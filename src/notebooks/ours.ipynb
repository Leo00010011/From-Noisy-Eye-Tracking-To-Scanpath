# %% [markdown]
# # Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import cv2
from utils.datasets.our_dataset import OurDataset

# %%
data = OurDataset()
data.summary()
img = data.img
img_list = [img.copy() for _ in range(3)]
gaze_list = data.get_eye_track([5,6,7])
# Out:
# sample_num:  62
# subject_num: 62
# samples_per_subject: 1
